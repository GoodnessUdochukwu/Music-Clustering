# %% [markdown]
# ## **K-Mediod Algorithm for Music Clustering**

# %%
# Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import silhouette_score

# %%
# Import data
music_data = pd.read_csv('Audio_files_1000.csv')
music_data
# Out:
#                                                    name  \
# 0                                          All Shook Up
# 1          I've Got You Under My Skin - Remastered 1998
# 2                               Smoke Gets In Your Eyes
# 3                               What'd I Say, Pt. 1 & 2
# 4                            Dream A Little Dream Of Me
# ...                                                 ...
# 1435  1812 Festival Overture, Op. 49: 1812 Overture,...
# 1436  Winter Fragments pour ensemble instrumental, s...
# 1437  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# 1438  Serenade For Strings In E, Op.22, B. 52: 1. Mo...
# 1439                               Ravel: Boléro, M. 81
#
#                         artist  danceability   energy  key  loudness  mode  \
# 0                Elvis Presley        0.6240  0.46800   10   -12.162     1
# 1                Frank Sinatra        0.5850  0.24700    1   -12.612     1
# 2                 The Platters        0.2900  0.22700    3   -13.060     1
# 3                  Ray Charles        0.5400  0.68100    4    -5.440     1
# 4              Ella Fitzgerald        0.4550  0.16700    0   -13.613     1
# ...                        ...           ...      ...  ...       ...   ...
# 1435  Pyotr Ilyich Tchaikovsky        0.2020  0.06940    3   -23.390     1
# 1436            Tristan Murail        0.1880  0.10100    6   -21.873     1
# 1437         Arnold Schoenberg        0.0596  0.00093    9   -42.959     1
# 1438            Antonín Dvořák        0.1330  0.02080    4   -29.443     1
# 1439             Maurice Ravel        0.3540  0.04870    5   -24.568     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.1320         0.881          0.000006    0.1440   0.9520   74.139
# 1          0.0400         0.452          0.000009    0.1070   0.5910  127.150
# 2          0.0311         0.944          0.000079    0.6170   0.2240  114.278
# 3          0.0508         0.808          0.000000    0.1620   0.7940   88.385
# 4          0.0739         0.918          0.000000    0.1730   0.4040   76.118
# ...           ...           ...               ...       ...      ...      ...
# 1435       0.0473         0.917          0.715000    0.0832   0.0655   87.906
# 1436       0.0442         0.855          0.426000    0.0694   0.0355   83.134
# 1437       0.0434         0.951          0.969000    0.0772   0.0344   71.573
# 1438       0.0419         0.883          0.505000    0.1110   0.0591   67.109
# 1439       0.0323         0.783          0.484000    0.2840   0.2530   64.120
#
#       type  duration_ms  time_signature                      id  \
# 0      NaN       117080               4  5ueyLj6e6oVaTY0KQ6yLaA
# 1      NaN       223760               4  3aEJMh1cXKEjgh52claxQp
# 2      NaN       157293               4  307XEC1IUwUs9ojlEFwH7f
# 3      NaN       307053               4  5yQ9iMZXGcr5rlO4hoLsP4
# 4      NaN       185067               4  3vFVS2WYHDG4KkWCNecvpn
# ...    ...          ...             ...                     ...
# 1435   NaN       995000               4  1aEhYlZtypmipA06SDJ4U3
# 1436   NaN       855000               4  1Gfqe7TAKklmuZf6hxsH6h
# 1437   NaN       238187               3  2XNwnFrdMDpismp0VUZ7cU
# 1438   NaN       314307               4  7ucDwgMtE3YJtEfTbuRhy0
# 1439   NaN       948787               3  7E1ErYYCn0lYjHODZ1qGuB
#
#                                                    html
# 0     https://open.spotify.com/track/5ueyLj6e6oVaTY0...
# 1     https://open.spotify.com/track/3aEJMh1cXKEjgh5...
# 2     https://open.spotify.com/track/307XEC1IUwUs9oj...
# 3     https://open.spotify.com/track/5yQ9iMZXGcr5rlO...
# 4     https://open.spotify.com/track/3vFVS2WYHDG4KkW...
# ...                                                 ...
# 1435  https://open.spotify.com/track/1aEhYlZtypmipA0...
# 1436  https://open.spotify.com/track/1Gfqe7TAKklmuZf...
# 1437  https://open.spotify.com/track/2XNwnFrdMDpismp...
# 1438  https://open.spotify.com/track/7ucDwgMtE3YJtEf...
# 1439  https://open.spotify.com/track/7E1ErYYCn0lYjHO...
#
# [1440 rows x 18 columns]

# %%
music_data['type'].isna().sum()
# Out:
# 1440

# %%
# Drop columns
music_data = music_data.drop(['type', 'html', 'id', 'artist'], axis=1)
music_data
# Out:
#                                                    name  danceability  \
# 0                                          All Shook Up        0.6240
# 1          I've Got You Under My Skin - Remastered 1998        0.5850
# 2                               Smoke Gets In Your Eyes        0.2900
# 3                               What'd I Say, Pt. 1 & 2        0.5400
# 4                            Dream A Little Dream Of Me        0.4550
# ...                                                 ...           ...
# 1435  1812 Festival Overture, Op. 49: 1812 Overture,...        0.2020
# 1436  Winter Fragments pour ensemble instrumental, s...        0.1880
# 1437  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...        0.0596
# 1438  Serenade For Strings In E, Op.22, B. 52: 1. Mo...        0.1330
# 1439                               Ravel: Boléro, M. 81        0.3540
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0     0.46800   10   -12.162     1       0.1320         0.881
# 1     0.24700    1   -12.612     1       0.0400         0.452
# 2     0.22700    3   -13.060     1       0.0311         0.944
# 3     0.68100    4    -5.440     1       0.0508         0.808
# 4     0.16700    0   -13.613     1       0.0739         0.918
# ...       ...  ...       ...   ...          ...           ...
# 1435  0.06940    3   -23.390     1       0.0473         0.917
# 1436  0.10100    6   -21.873     1       0.0442         0.855
# 1437  0.00093    9   -42.959     1       0.0434         0.951
# 1438  0.02080    4   -29.443     1       0.0419         0.883
# 1439  0.04870    5   -24.568     1       0.0323         0.783
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000006    0.1440   0.9520   74.139       117080
# 1             0.000009    0.1070   0.5910  127.150       223760
# 2             0.000079    0.6170   0.2240  114.278       157293
# 3             0.000000    0.1620   0.7940   88.385       307053
# 4             0.000000    0.1730   0.4040   76.118       185067
# ...                ...       ...      ...      ...          ...
# 1435          0.715000    0.0832   0.0655   87.906       995000
# 1436          0.426000    0.0694   0.0355   83.134       855000
# 1437          0.969000    0.0772   0.0344   71.573       238187
# 1438          0.505000    0.1110   0.0591   67.109       314307
# 1439          0.484000    0.2840   0.2530   64.120       948787
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1435               4
# 1436               4
# 1437               3
# 1438               4
# 1439               3
#
# [1440 rows x 14 columns]

# %%
# Reindex the music_data
idx = list(music_data['name'])
music_data = music_data.drop('name', axis=1)
music_data.index = idx
music_data
# Out:
#                                                     danceability   energy  \
# All Shook Up                                              0.6240  0.46800
# I've Got You Under My Skin - Remastered 1998              0.5850  0.24700
# Smoke Gets In Your Eyes                                   0.2900  0.22700
# What'd I Say, Pt. 1 & 2                                   0.5400  0.68100
# Dream A Little Dream Of Me                                0.4550  0.16700
# ...                                                          ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...        0.2020  0.06940
# Winter Fragments pour ensemble instrumental, so...        0.1880  0.10100
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...        0.0596  0.00093
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0.1330  0.02080
# Ravel: Boléro, M. 81                                      0.3540  0.04870
#
#                                                     key  loudness  mode  \
# All Shook Up                                         10   -12.162     1
# I've Got You Under My Skin - Remastered 1998          1   -12.612     1
# Smoke Gets In Your Eyes                               3   -13.060     1
# What'd I Say, Pt. 1 & 2                               4    -5.440     1
# Dream A Little Dream Of Me                            0   -13.613     1
# ...                                                 ...       ...   ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...    3   -23.390     1
# Winter Fragments pour ensemble instrumental, so...    6   -21.873     1
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    9   -42.959     1
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...    4   -29.443     1
# Ravel: Boléro, M. 81                                  5   -24.568     1
#
#                                                     speechiness  acousticness  \
# All Shook Up                                             0.1320         0.881
# I've Got You Under My Skin - Remastered 1998             0.0400         0.452
# Smoke Gets In Your Eyes                                  0.0311         0.944
# What'd I Say, Pt. 1 & 2                                  0.0508         0.808
# Dream A Little Dream Of Me                               0.0739         0.918
# ...                                                         ...           ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...       0.0473         0.917
# Winter Fragments pour ensemble instrumental, so...       0.0442         0.855
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       0.0434         0.951
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...       0.0419         0.883
# Ravel: Boléro, M. 81                                     0.0323         0.783
#
#                                                     instrumentalness  \
# All Shook Up                                                0.000006
# I've Got You Under My Skin - Remastered 1998                0.000009
# Smoke Gets In Your Eyes                                     0.000079
# What'd I Say, Pt. 1 & 2                                     0.000000
# Dream A Little Dream Of Me                                  0.000000
# ...                                                              ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...          0.715000
# Winter Fragments pour ensemble instrumental, so...          0.426000
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          0.969000
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...          0.505000
# Ravel: Boléro, M. 81                                        0.484000
#
#                                                     liveness  valence  \
# All Shook Up                                          0.1440   0.9520
# I've Got You Under My Skin - Remastered 1998          0.1070   0.5910
# Smoke Gets In Your Eyes                               0.6170   0.2240
# What'd I Say, Pt. 1 & 2                               0.1620   0.7940
# Dream A Little Dream Of Me                            0.1730   0.4040
# ...                                                      ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...    0.0832   0.0655
# Winter Fragments pour ensemble instrumental, so...    0.0694   0.0355
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    0.0772   0.0344
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...    0.1110   0.0591
# Ravel: Boléro, M. 81                                  0.2840   0.2530
#
#                                                       tempo  duration_ms  \
# All Shook Up                                         74.139       117080
# I've Got You Under My Skin - Remastered 1998        127.150       223760
# Smoke Gets In Your Eyes                             114.278       157293
# What'd I Say, Pt. 1 & 2                              88.385       307053
# Dream A Little Dream Of Me                           76.118       185067
# ...                                                     ...          ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...   87.906       995000
# Winter Fragments pour ensemble instrumental, so...   83.134       855000
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   71.573       238187
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...   67.109       314307
# Ravel: Boléro, M. 81                                 64.120       948787
#
#                                                     time_signature
# All Shook Up                                                     4
# I've Got You Under My Skin - Remastered 1998                     4
# Smoke Gets In Your Eyes                                          4
# What'd I Say, Pt. 1 & 2                                          4
# Dream A Little Dream Of Me                                       4
# ...                                                            ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...               4
# Winter Fragments pour ensemble instrumental, so...               4
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...               3
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...               4
# Ravel: Boléro, M. 81                                             3
#
# [1440 rows x 13 columns]

# %%
music_data.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
music_data.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
music_data.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean       0.538917     0.494241     5.154861   -11.098032     0.663194
# std        0.219193     0.281917     3.540932     6.979107     0.472782
# min        0.059600     0.000020     0.000000   -44.406000     0.000000
# 25%        0.386000     0.243000     2.000000   -14.927250     0.000000
# 50%        0.562000     0.529500     5.000000    -8.939500     1.000000
# 75%        0.710250     0.733000     8.000000    -5.677250     1.000000
# max        0.964000     0.996000    11.000000     1.085000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  1440.000000   1440.000000       1440.000000  1440.000000  1440.000000
# mean      0.086273      0.469774          0.188482     0.174391     0.472576
# std       0.086193      0.374637          0.336594     0.146007     0.287807
# min       0.023200      0.000002          0.000000     0.020700     0.019600
# 25%       0.038400      0.083025          0.000000     0.090700     0.214750
# 50%       0.048200      0.419000          0.000127     0.118000     0.476500
# 75%       0.088825      0.869250          0.159750     0.203000     0.720000
# max       0.576000      0.996000          0.985000     0.985000     0.985000
#
#              tempo   duration_ms  time_signature
# count  1440.000000  1.440000e+03     1440.000000
# mean    115.249066  2.912083e+05        3.889583
# std      31.611805  2.280920e+05        0.446937
# min      49.689000  6.275800e+04        1.000000
# 25%      91.014250  1.930300e+05        4.000000
# 50%     110.008000  2.336965e+05        4.000000
# 75%     135.587000  3.080625e+05        4.000000
# max     206.313000  3.815787e+06        5.000000

# %% [markdown]
# #### **Visualize the data**

# %%
# Columns in dataframe
# 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature'

# %%
plt.subplots(figsize=(12, 8))
sns.boxplot(data=music_data, y='speechiness')
# plt.xticks(rotation=90)
# plt.ylim(0, 0.5)
plt.show()

# %%
# outliers: speechiness, loudness, instrumentalness, liveness, tempo, duration_ms,  

# good data: danceability, energy, acousticness, valence

# %%
music_data = music_data.drop('key', axis=1)
music_data
# Out:
#                                                     danceability   energy  \
# All Shook Up                                              0.6240  0.46800
# I've Got You Under My Skin - Remastered 1998              0.5850  0.24700
# Smoke Gets In Your Eyes                                   0.2900  0.22700
# What'd I Say, Pt. 1 & 2                                   0.5400  0.68100
# Dream A Little Dream Of Me                                0.4550  0.16700
# ...                                                          ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...        0.2020  0.06940
# Winter Fragments pour ensemble instrumental, so...        0.1880  0.10100
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...        0.0596  0.00093
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0.1330  0.02080
# Ravel: Boléro, M. 81                                      0.3540  0.04870
#
#                                                     loudness  mode  \
# All Shook Up                                         -12.162     1
# I've Got You Under My Skin - Remastered 1998         -12.612     1
# Smoke Gets In Your Eyes                              -13.060     1
# What'd I Say, Pt. 1 & 2                               -5.440     1
# Dream A Little Dream Of Me                           -13.613     1
# ...                                                      ...   ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...   -23.390     1
# Winter Fragments pour ensemble instrumental, so...   -21.873     1
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   -42.959     1
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...   -29.443     1
# Ravel: Boléro, M. 81                                 -24.568     1
#
#                                                     speechiness  acousticness  \
# All Shook Up                                             0.1320         0.881
# I've Got You Under My Skin - Remastered 1998             0.0400         0.452
# Smoke Gets In Your Eyes                                  0.0311         0.944
# What'd I Say, Pt. 1 & 2                                  0.0508         0.808
# Dream A Little Dream Of Me                               0.0739         0.918
# ...                                                         ...           ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...       0.0473         0.917
# Winter Fragments pour ensemble instrumental, so...       0.0442         0.855
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       0.0434         0.951
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...       0.0419         0.883
# Ravel: Boléro, M. 81                                     0.0323         0.783
#
#                                                     instrumentalness  \
# All Shook Up                                                0.000006
# I've Got You Under My Skin - Remastered 1998                0.000009
# Smoke Gets In Your Eyes                                     0.000079
# What'd I Say, Pt. 1 & 2                                     0.000000
# Dream A Little Dream Of Me                                  0.000000
# ...                                                              ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...          0.715000
# Winter Fragments pour ensemble instrumental, so...          0.426000
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          0.969000
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...          0.505000
# Ravel: Boléro, M. 81                                        0.484000
#
#                                                     liveness  valence  \
# All Shook Up                                          0.1440   0.9520
# I've Got You Under My Skin - Remastered 1998          0.1070   0.5910
# Smoke Gets In Your Eyes                               0.6170   0.2240
# What'd I Say, Pt. 1 & 2                               0.1620   0.7940
# Dream A Little Dream Of Me                            0.1730   0.4040
# ...                                                      ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...    0.0832   0.0655
# Winter Fragments pour ensemble instrumental, so...    0.0694   0.0355
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    0.0772   0.0344
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...    0.1110   0.0591
# Ravel: Boléro, M. 81                                  0.2840   0.2530
#
#                                                       tempo  duration_ms  \
# All Shook Up                                         74.139       117080
# I've Got You Under My Skin - Remastered 1998        127.150       223760
# Smoke Gets In Your Eyes                             114.278       157293
# What'd I Say, Pt. 1 & 2                              88.385       307053
# Dream A Little Dream Of Me                           76.118       185067
# ...                                                     ...          ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...   87.906       995000
# Winter Fragments pour ensemble instrumental, so...   83.134       855000
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   71.573       238187
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...   67.109       314307
# Ravel: Boléro, M. 81                                 64.120       948787
#
#                                                     time_signature
# All Shook Up                                                     4
# I've Got You Under My Skin - Remastered 1998                     4
# Smoke Gets In Your Eyes                                          4
# What'd I Say, Pt. 1 & 2                                          4
# Dream A Little Dream Of Me                                       4
# ...                                                            ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...               4
# Winter Fragments pour ensemble instrumental, so...               4
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...               3
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...               4
# Ravel: Boléro, M. 81                                             3
#
# [1440 rows x 12 columns]

# %%
music_data1 = music_data[['speechiness', 'loudness', 'instrumentalness', 'liveness', 'tempo', 'duration_ms']]
music_data2 = music_data.drop(['speechiness', 'loudness', 'instrumentalness', 'liveness', 'tempo', 'duration_ms'], axis=1).reset_index(drop=True)

# %%
music_data2
# Out:
#       danceability   energy  mode  acousticness  valence  time_signature
# 0           0.6240  0.46800     1         0.881   0.9520               4
# 1           0.5850  0.24700     1         0.452   0.5910               4
# 2           0.2900  0.22700     1         0.944   0.2240               4
# 3           0.5400  0.68100     1         0.808   0.7940               4
# 4           0.4550  0.16700     1         0.918   0.4040               4
# ...            ...      ...   ...           ...      ...             ...
# 1435        0.2020  0.06940     1         0.917   0.0655               4
# 1436        0.1880  0.10100     1         0.855   0.0355               4
# 1437        0.0596  0.00093     1         0.951   0.0344               3
# 1438        0.1330  0.02080     1         0.883   0.0591               4
# 1439        0.3540  0.04870     1         0.783   0.2530               3
#
# [1440 rows x 6 columns]

# %%
music_data1
# Out:
#                                                     speechiness  loudness  \
# All Shook Up                                             0.1320   -12.162
# I've Got You Under My Skin - Remastered 1998             0.0400   -12.612
# Smoke Gets In Your Eyes                                  0.0311   -13.060
# What'd I Say, Pt. 1 & 2                                  0.0508    -5.440
# Dream A Little Dream Of Me                               0.0739   -13.613
# ...                                                         ...       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...       0.0473   -23.390
# Winter Fragments pour ensemble instrumental, so...       0.0442   -21.873
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       0.0434   -42.959
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...       0.0419   -29.443
# Ravel: Boléro, M. 81                                     0.0323   -24.568
#
#                                                     instrumentalness  \
# All Shook Up                                                0.000006
# I've Got You Under My Skin - Remastered 1998                0.000009
# Smoke Gets In Your Eyes                                     0.000079
# What'd I Say, Pt. 1 & 2                                     0.000000
# Dream A Little Dream Of Me                                  0.000000
# ...                                                              ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...          0.715000
# Winter Fragments pour ensemble instrumental, so...          0.426000
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          0.969000
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...          0.505000
# Ravel: Boléro, M. 81                                        0.484000
#
#                                                     liveness    tempo  \
# All Shook Up                                          0.1440   74.139
# I've Got You Under My Skin - Remastered 1998          0.1070  127.150
# Smoke Gets In Your Eyes                               0.6170  114.278
# What'd I Say, Pt. 1 & 2                               0.1620   88.385
# Dream A Little Dream Of Me                            0.1730   76.118
# ...                                                      ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...    0.0832   87.906
# Winter Fragments pour ensemble instrumental, so...    0.0694   83.134
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    0.0772   71.573
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...    0.1110   67.109
# Ravel: Boléro, M. 81                                  0.2840   64.120
#
#                                                     duration_ms
# All Shook Up                                             117080
# I've Got You Under My Skin - Remastered 1998             223760
# Smoke Gets In Your Eyes                                  157293
# What'd I Say, Pt. 1 & 2                                  307053
# Dream A Little Dream Of Me                               185067
# ...                                                         ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...       995000
# Winter Fragments pour ensemble instrumental, so...       855000
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       238187
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...       314307
# Ravel: Boléro, M. 81                                     948787
#
# [1440 rows x 6 columns]

# %% [markdown]
# #### **Scale the columns with outliers**

# %%
music_data1a = pd.DataFrame(RobustScaler(with_centering=False).fit_transform(music_data1))
music_data1a.columns = ['speechiness', 'loudness', 'instrumentalness', 'liveness', 'tempo', 'duration_ms']
music_data1a
# Out:
#       speechiness  loudness  instrumentalness  liveness     tempo  duration_ms
# 0        2.617749 -1.314811          0.000040  1.282280  1.663326     1.017799
# 1        0.793257 -1.363459          0.000055  0.952805  2.852640     1.945189
# 2        0.616758 -1.411892          0.000498  5.494212  2.563853     1.367379
# 3        1.007437 -0.588108          0.000000  1.442565  1.982938     2.669272
# 4        1.465543 -1.471676          0.000000  1.540516  1.707725     1.608824
# ...           ...       ...               ...       ...       ...          ...
# 1435     0.938027 -2.528649          4.475743  0.740873  1.972192     8.649729
# 1436     0.876549 -2.364649          2.666667  0.617988  1.865131     7.432682
# 1437     0.860684 -4.644216          6.065728  0.687444  1.605757     2.070606
# 1438     0.830937 -3.183027          3.161189  0.988424  1.505606     2.732332
# 1439     0.640555 -2.656000          3.029734  2.528940  1.438547     8.247991
#
# [1440 rows x 6 columns]

# %%
music_data1a.describe()
# Out:
#        speechiness     loudness  instrumentalness     liveness        tempo  \
# count  1440.000000  1440.000000       1440.000000  1440.000000  1440.000000
# mean      1.710920    -1.199787          1.179855     1.552903     2.585640
# std       1.709322     0.754498          2.107003     1.300148     0.709218
# min       0.460089    -4.800649          0.000000     0.184328     1.114784
# 25%       0.761527    -1.613757          0.000000     0.807658     2.041926
# 50%       0.955875    -0.966432          0.000795     1.050757     2.468055
# 75%       1.761527    -0.613757          1.000000     1.807658     3.041926
# max      11.422905     0.117297          6.165884     8.771149     4.628680
#
#        duration_ms
# count  1440.000000
# mean      2.531531
# std       1.982849
# min       0.545568
# 25%       1.678048
# 50%       2.031569
# 75%       2.678048
# max      33.171382

# %%
music_data1b = pd.DataFrame(RobustScaler(with_centering=True).fit_transform(music_data1))
music_data1b.columns = ['speechiness', 'loudness', 'instrumentalness', 'liveness', 'tempo', 'duration_ms']
music_data1b
# Out:
#       speechiness  loudness  instrumentalness  liveness     tempo  duration_ms
# 0        1.661874 -0.348378         -0.000755  0.231523 -0.804729    -1.013770
# 1       -0.162618 -0.397027         -0.000740 -0.097952  0.384585    -0.086380
# 2       -0.339118 -0.445459         -0.000297  4.443455  0.095798    -0.664191
# 3        0.051562  0.378324         -0.000795  0.391808 -0.485117     0.637702
# 4        0.509668 -0.505243         -0.000795  0.489760 -0.760330    -0.422746
# ...           ...       ...               ...       ...       ...          ...
# 1435    -0.017848 -1.562216          4.474948 -0.309884 -0.495864     6.618160
# 1436    -0.079326 -1.398216          2.665872 -0.432769 -0.602924     5.401113
# 1437    -0.095191 -3.677784          6.064933 -0.363313 -0.862298     0.039037
# 1438    -0.124938 -2.216595          3.160394 -0.062333 -0.962449     0.700763
# 1439    -0.315320 -1.689568          3.028939  1.478183 -1.029508     6.216421
#
# [1440 rows x 6 columns]

# %%
music_data_combd1 = pd.concat([music_data2, music_data1a], axis=1)
music_data_combd1.index = list(music_data.index)
music_data_combd1
# Out:
#                                                     danceability   energy  \
# All Shook Up                                              0.6240  0.46800
# I've Got You Under My Skin - Remastered 1998              0.5850  0.24700
# Smoke Gets In Your Eyes                                   0.2900  0.22700
# What'd I Say, Pt. 1 & 2                                   0.5400  0.68100
# Dream A Little Dream Of Me                                0.4550  0.16700
# ...                                                          ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...        0.2020  0.06940
# Winter Fragments pour ensemble instrumental, so...        0.1880  0.10100
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...        0.0596  0.00093
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0.1330  0.02080
# Ravel: Boléro, M. 81                                      0.3540  0.04870
#
#                                                     mode  acousticness  \
# All Shook Up                                           1         0.881
# I've Got You Under My Skin - Remastered 1998           1         0.452
# Smoke Gets In Your Eyes                                1         0.944
# What'd I Say, Pt. 1 & 2                                1         0.808
# Dream A Little Dream Of Me                             1         0.918
# ...                                                  ...           ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...     1         0.917
# Winter Fragments pour ensemble instrumental, so...     1         0.855
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     1         0.951
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...     1         0.883
# Ravel: Boléro, M. 81                                   1         0.783
#
#                                                     valence  time_signature  \
# All Shook Up                                         0.9520               4
# I've Got You Under My Skin - Remastered 1998         0.5910               4
# Smoke Gets In Your Eyes                              0.2240               4
# What'd I Say, Pt. 1 & 2                              0.7940               4
# Dream A Little Dream Of Me                           0.4040               4
# ...                                                     ...             ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...   0.0655               4
# Winter Fragments pour ensemble instrumental, so...   0.0355               4
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   0.0344               3
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...   0.0591               4
# Ravel: Boléro, M. 81                                 0.2530               3
#
#                                                     speechiness  loudness  \
# All Shook Up                                           2.617749 -1.314811
# I've Got You Under My Skin - Remastered 1998           0.793257 -1.363459
# Smoke Gets In Your Eyes                                0.616758 -1.411892
# What'd I Say, Pt. 1 & 2                                1.007437 -0.588108
# Dream A Little Dream Of Me                             1.465543 -1.471676
# ...                                                         ...       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...     0.938027 -2.528649
# Winter Fragments pour ensemble instrumental, so...     0.876549 -2.364649
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     0.860684 -4.644216
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...     0.830937 -3.183027
# Ravel: Boléro, M. 81                                   0.640555 -2.656000
#
#                                                     instrumentalness  \
# All Shook Up                                                0.000040
# I've Got You Under My Skin - Remastered 1998                0.000055
# Smoke Gets In Your Eyes                                     0.000498
# What'd I Say, Pt. 1 & 2                                     0.000000
# Dream A Little Dream Of Me                                  0.000000
# ...                                                              ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...          4.475743
# Winter Fragments pour ensemble instrumental, so...          2.666667
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          6.065728
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...          3.161189
# Ravel: Boléro, M. 81                                        3.029734
#
#                                                     liveness     tempo  \
# All Shook Up                                        1.282280  1.663326
# I've Got You Under My Skin - Remastered 1998        0.952805  2.852640
# Smoke Gets In Your Eyes                             5.494212  2.563853
# What'd I Say, Pt. 1 & 2                             1.442565  1.982938
# Dream A Little Dream Of Me                          1.540516  1.707725
# ...                                                      ...       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...  0.740873  1.972192
# Winter Fragments pour ensemble instrumental, so...  0.617988  1.865131
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.687444  1.605757
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.988424  1.505606
# Ravel: Boléro, M. 81                                2.528940  1.438547
#
#                                                     duration_ms
# All Shook Up                                           1.017799
# I've Got You Under My Skin - Remastered 1998           1.945189
# Smoke Gets In Your Eyes                                1.367379
# What'd I Say, Pt. 1 & 2                                2.669272
# Dream A Little Dream Of Me                             1.608824
# ...                                                         ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...     8.649729
# Winter Fragments pour ensemble instrumental, so...     7.432682
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     2.070606
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...     2.732332
# Ravel: Boléro, M. 81                                   8.247991
#
# [1440 rows x 12 columns]

# %%
music_data_combd1.describe()
# Out:
#        danceability       energy         mode  acousticness      valence  \
# count   1440.000000  1440.000000  1440.000000   1440.000000  1440.000000
# mean       0.538917     0.494241     0.663194      0.469774     0.472576
# std        0.219193     0.281917     0.472782      0.374637     0.287807
# min        0.059600     0.000020     0.000000      0.000002     0.019600
# 25%        0.386000     0.243000     0.000000      0.083025     0.214750
# 50%        0.562000     0.529500     1.000000      0.419000     0.476500
# 75%        0.710250     0.733000     1.000000      0.869250     0.720000
# max        0.964000     0.996000     1.000000      0.996000     0.985000
#
#        time_signature  speechiness     loudness  instrumentalness  \
# count     1440.000000  1440.000000  1440.000000       1440.000000
# mean         3.889583     1.710920    -1.199787          1.179855
# std          0.446937     1.709322     0.754498          2.107003
# min          1.000000     0.460089    -4.800649          0.000000
# 25%          4.000000     0.761527    -1.613757          0.000000
# 50%          4.000000     0.955875    -0.966432          0.000795
# 75%          4.000000     1.761527    -0.613757          1.000000
# max          5.000000    11.422905     0.117297          6.165884
#
#           liveness        tempo  duration_ms
# count  1440.000000  1440.000000  1440.000000
# mean      1.552903     2.585640     2.531531
# std       1.300148     0.709218     1.982849
# min       0.184328     1.114784     0.545568
# 25%       0.807658     2.041926     1.678048
# 50%       1.050757     2.468055     2.031569
# 75%       1.807658     3.041926     2.678048
# max       8.771149     4.628680    33.171382

# %%
music_data_combd2 = pd.concat([music_data2, music_data1b], axis=1)
music_data_combd2.index = list(music_data.index)
music_data_combd2
# Out:
#                                                     danceability   energy  \
# All Shook Up                                              0.6240  0.46800
# I've Got You Under My Skin - Remastered 1998              0.5850  0.24700
# Smoke Gets In Your Eyes                                   0.2900  0.22700
# What'd I Say, Pt. 1 & 2                                   0.5400  0.68100
# Dream A Little Dream Of Me                                0.4550  0.16700
# ...                                                          ...      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...        0.2020  0.06940
# Winter Fragments pour ensemble instrumental, so...        0.1880  0.10100
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...        0.0596  0.00093
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0.1330  0.02080
# Ravel: Boléro, M. 81                                      0.3540  0.04870
#
#                                                     mode  acousticness  \
# All Shook Up                                           1         0.881
# I've Got You Under My Skin - Remastered 1998           1         0.452
# Smoke Gets In Your Eyes                                1         0.944
# What'd I Say, Pt. 1 & 2                                1         0.808
# Dream A Little Dream Of Me                             1         0.918
# ...                                                  ...           ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...     1         0.917
# Winter Fragments pour ensemble instrumental, so...     1         0.855
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     1         0.951
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...     1         0.883
# Ravel: Boléro, M. 81                                   1         0.783
#
#                                                     valence  time_signature  \
# All Shook Up                                         0.9520               4
# I've Got You Under My Skin - Remastered 1998         0.5910               4
# Smoke Gets In Your Eyes                              0.2240               4
# What'd I Say, Pt. 1 & 2                              0.7940               4
# Dream A Little Dream Of Me                           0.4040               4
# ...                                                     ...             ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...   0.0655               4
# Winter Fragments pour ensemble instrumental, so...   0.0355               4
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   0.0344               3
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...   0.0591               4
# Ravel: Boléro, M. 81                                 0.2530               3
#
#                                                     speechiness  loudness  \
# All Shook Up                                           1.661874 -0.348378
# I've Got You Under My Skin - Remastered 1998          -0.162618 -0.397027
# Smoke Gets In Your Eyes                               -0.339118 -0.445459
# What'd I Say, Pt. 1 & 2                                0.051562  0.378324
# Dream A Little Dream Of Me                             0.509668 -0.505243
# ...                                                         ...       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...    -0.017848 -1.562216
# Winter Fragments pour ensemble instrumental, so...    -0.079326 -1.398216
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    -0.095191 -3.677784
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...    -0.124938 -2.216595
# Ravel: Boléro, M. 81                                  -0.315320 -1.689568
#
#                                                     instrumentalness  \
# All Shook Up                                               -0.000755
# I've Got You Under My Skin - Remastered 1998               -0.000740
# Smoke Gets In Your Eyes                                    -0.000297
# What'd I Say, Pt. 1 & 2                                    -0.000795
# Dream A Little Dream Of Me                                 -0.000795
# ...                                                              ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...          4.474948
# Winter Fragments pour ensemble instrumental, so...          2.665872
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          6.064933
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...          3.160394
# Ravel: Boléro, M. 81                                        3.028939
#
#                                                     liveness     tempo  \
# All Shook Up                                        0.231523 -0.804729
# I've Got You Under My Skin - Remastered 1998       -0.097952  0.384585
# Smoke Gets In Your Eyes                             4.443455  0.095798
# What'd I Say, Pt. 1 & 2                             0.391808 -0.485117
# Dream A Little Dream Of Me                          0.489760 -0.760330
# ...                                                      ...       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ... -0.309884 -0.495864
# Winter Fragments pour ensemble instrumental, so... -0.432769 -0.602924
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.363313 -0.862298
# Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.062333 -0.962449
# Ravel: Boléro, M. 81                                1.478183 -1.029508
#
#                                                     duration_ms
# All Shook Up                                          -1.013770
# I've Got You Under My Skin - Remastered 1998          -0.086380
# Smoke Gets In Your Eyes                               -0.664191
# What'd I Say, Pt. 1 & 2                                0.637702
# Dream A Little Dream Of Me                            -0.422746
# ...                                                         ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ...     6.618160
# Winter Fragments pour ensemble instrumental, so...     5.401113
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     0.039037
# Serenade For Strings In E, Op.22, B. 52: 1. Mod...     0.700763
# Ravel: Boléro, M. 81                                   6.216421
#
# [1440 rows x 12 columns]

# %%
music_data_combd2.describe()
# Out:
#        danceability       energy         mode  acousticness      valence  \
# count   1440.000000  1440.000000  1440.000000   1440.000000  1440.000000
# mean       0.538917     0.494241     0.663194      0.469774     0.472576
# std        0.219193     0.281917     0.472782      0.374637     0.287807
# min        0.059600     0.000020     0.000000      0.000002     0.019600
# 25%        0.386000     0.243000     0.000000      0.083025     0.214750
# 50%        0.562000     0.529500     1.000000      0.419000     0.476500
# 75%        0.710250     0.733000     1.000000      0.869250     0.720000
# max        0.964000     0.996000     1.000000      0.996000     0.985000
#
#        time_signature  speechiness      loudness  instrumentalness  \
# count     1440.000000  1440.000000  1.440000e+03       1440.000000
# mean         3.889583     0.755045 -2.333548e-01          1.179060
# std          0.446937     1.709322  7.544981e-01          2.107003
# min          1.000000    -0.495786 -3.834216e+00         -0.000795
# 25%          4.000000    -0.194348 -6.473243e-01         -0.000795
# 50%          4.000000     0.000000 -9.600610e-17          0.000000
# 75%          4.000000     0.805652  3.526757e-01          0.999205
# max          5.000000    10.467030  1.083730e+00          6.165089
#
#           liveness         tempo  duration_ms
# count  1440.000000  1.440000e+03  1440.000000
# mean      0.502146  1.175845e-01     0.499962
# std       1.300148  7.092182e-01     1.982849
# min      -0.866429 -1.353271e+00    -1.486002
# 25%      -0.243099 -4.261292e-01    -0.353522
# 50%       0.000000 -1.594048e-16     0.000000
# 75%       0.756901  5.738708e-01     0.646478
# max       7.720392  2.160625e+00    31.139813

# %% [markdown]
# #### **Perform K-Mediods Clustering to Calculate Inertia and Silhouette Scores**

# %%
inertia_list1 = []
sil_scores1 = []

for i in range(2, 40):
    kmed = KMedoids(n_clusters=i, method='pam').fit(music_data_combd1)
    inertia_list1.append(round(kmed.inertia_))
    sil_scores1.append(silhouette_score(music_data_combd1, kmed.labels_))

# %%
inertia_list2 = []
sil_scores2 = []

for i in range(2, 40):
    kmed = KMedoids(n_clusters=i, method='pam').fit(music_data_combd2)
    inertia_list2.append(round(kmed.inertia_))
    sil_scores2.append(silhouette_score(music_data_combd2, kmed.labels_))

# %% [markdown]
# #### **Visualize the Results**

# %%
plt.figure(figsize=(10, 8))
plt.plot(range(len(inertia_list1)), inertia_list1)
plt.title('Inertia vs Cluster_num')
plt.xlabel('Num._of_Clusters')
plt.ylabel('Inertia_score')
plt.show();

# %%
plt.figure(figsize=(10, 8))
plt.plot(range(len(sil_scores1)), sil_scores1, marker='o')
plt.title('Silhouette_Score vs Cluster_num')
plt.xlabel('Num._of_Clusters')
plt.ylabel('Silhouette_Score')
plt.show();

# %%
plt.figure(figsize=(10, 8))
plt.plot(range(len(inertia_list2)), inertia_list2)
plt.title('Inertia vs Cluster_num')
plt.xlabel('Num._of_Clusters')
plt.ylabel('Inertia_score')
plt.show();

# %%
plt.figure(figsize=(10, 8))
plt.plot(range(len(sil_scores2)), sil_scores2, marker='o')
plt.title('Silhouette_Score vs Cluster_num')
plt.xlabel('Num._of_Clusters')
plt.ylabel('Silhouette_Score')
plt.show();

# %% [markdown]
# #### **Using or not using centering on Robust Scaler had no effect on the final outcome.**
#
# #### **Based on the silhouette score, robustScaling achieves optimal clustering of 9**
